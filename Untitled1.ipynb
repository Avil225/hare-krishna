# %%
from scipy import stats
x = [1 , 6 ,4 ,33 , 3 ,5 ,4 ,8 ,2 ,2 , 5 , 5 ,5]
y= stats.mode(x)
print(y)
# Out:
# ModeResult(mode=array([5]), count=array([4]))

# %%
import numpy 
x = [1 , 1 ,1 , 1 ,1 ,1 ]
y = numpy.std(x)
print(y)
# Out:
# 0.0

# %%
import numpy
ages = [5,31,43,48,50,41,7,11,15,39,80,82,32,2,8,6,25,36,27,61,31]
percentile = numpy.percentile(ages,50)
print(percentile)
# Out:
# 31.0

# %%
import numpy
import matplotlib.pyplot as plt 
x = numpy.random.uniform(0.0 , 5.0 , 10000)
plt.hist(x , 5)
plt.show()

# %%
import numpy
import matplotlib.pyplot as plt

x = numpy.random.normal(5.0, 1.0, 100000)

plt.hist(x, 100)
plt.show()

# %%
import matplotlib.pyplot as plt 
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]
plt.scatter(x , y )
plt.show()

# %%
import numpy
import matplotlib.pyplot as plt
x = numpy.random.normal(5.0 , 1.0 , 1000)
y = numpy.random.normal(10.0 , 2.0 , 1000 )
plt.scatter(x , y)
plt.show()
